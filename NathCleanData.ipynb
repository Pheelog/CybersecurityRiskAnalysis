# %%
import pandas as pd

# %%
url1 = r'\Users\Anih Nathan\OneDrive\Desktop\cyber data\set1.csv'
url2 = r'\Users\Anih Nathan\OneDrive\Desktop\cyber data\set2.csv'
url3 = r'\Users\Anih Nathan\OneDrive\Desktop\cyber data\set3.csv'
url4 = r'\Users\Anih Nathan\OneDrive\Desktop\cyber data\set4.csv'
url5 = r'\Users\Anih Nathan\OneDrive\Desktop\cyber data\set5.csv'

df1 = pd.read_csv(url1)
df2 = pd.read_csv(url2)
df3 = pd.read_csv(url3)
df4 = pd.read_csv(url4)
df5 = pd.read_csv(url5)

# %%
dfall=df1.append(df2, ignore_index=True)
# Out:
# C:\Users\Anih Nathan\AppData\Local\Temp\ipykernel_9584\3957060377.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfall=df1.append(df2, ignore_index=True)

# %%
dfall=dfall.append(df3, ignore_index=True)
# Out:
# C:\Users\Anih Nathan\AppData\Local\Temp\ipykernel_9584\2955941068.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfall=dfall.append(df3, ignore_index=True)

# %%
dfall=dfall.append(df4, ignore_index=True)
# Out:
# C:\Users\Anih Nathan\AppData\Local\Temp\ipykernel_9584\3602219865.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfall=dfall.append(df4, ignore_index=True)

# %%
dfall =dfall.append(df5,ignore_index=True)
# Out:
# C:\Users\Anih Nathan\AppData\Local\Temp\ipykernel_9584\2969777103.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfall =dfall.append(df5,ignore_index=True)

# %%
dfall.isnull().sum()
# Out:
# cve_id                   0
# vendor_project           0
# product                  5
# vulnerability_name       0
# date_added               0
# short_description       30
# required_action          0
# due_date                 0
# grp                      0
# pub_date               878
# cvss                  1500
# cwe                    894
# vector                1500
# complexity            1500
# severity              1500
# dtype: int64

# %%
dfall.dropna(axis=0, inplace=True)

# %%
dfall.isnull().sum()
# Out:
# cve_id                0
# vendor_project        0
# product               0
# vulnerability_name    0
# date_added            0
# short_description     0
# required_action       0
# due_date              0
# grp                   0
# pub_date              0
# cvss                  0
# cwe                   0
# vector                0
# complexity            0
# severity              0
# dtype: int64

# %%
dfall.drop_duplicates(subset='cve_id', inplace=True)

# %%
dfall.describe(include='all')
# Out:
#                 cve_id vendor_project  product  \
# count              622            622      622
# unique             622            124      307
# top     CVE-2021-27104      microsoft  Windows
# freq                 1            171       63
# mean               NaN            NaN      NaN
# std                NaN            NaN      NaN
# min                NaN            NaN      NaN
# 25%                NaN            NaN      NaN
# 50%                NaN            NaN      NaN
# 75%                NaN            NaN      NaN
# max                NaN            NaN      NaN
#
#                                        vulnerability_name  date_added  \
# count                                                 622         622
# unique                                                517          40
# top     Microsoft Win32k Privilege Escalation Vulnerab...  2021-11-03
# freq                                                   12         276
# ...

# %%
pd.set_option('display.max_rows',1000)

# %%
dfall
# Out:
#                 cve_id       vendor_project  \
# 0       CVE-2021-27104            accellion
# 1       CVE-2021-27102            accellion
# 2       CVE-2021-27101            accellion
# 3       CVE-2021-27103            accellion
# 4       CVE-2021-21017                adobe
# 5       CVE-2021-28550                adobe
# 6        CVE-2018-4939                adobe
# 7       CVE-2018-15961                adobe
# 8        CVE-2018-4878                adobe
# 9        CVE-2020-5735              amcrest
# 13       CVE-2017-9805               apache
# 14      CVE-2021-42013               apache
# 15      CVE-2021-41773               apache
# 16       CVE-2019-0211               apache
# 17       CVE-2016-4437               apache
# 18      CVE-2019-17558               apache
# 19      CVE-2020-17530               apache
# 20       CVE-2017-5638               apache
# 21      CVE-2018-11776               apache
# 22      CVE-2021-30858                apple
# ...
